# %% [markdown]
# ## Arch User Repository Data
#
# I'm interested in exploring the meta data on the Arch User Repository (AUR). This notebook will show how I scraped data from [https://www.archlinux.org/packages/](https://www.archlinux.org/packages/) and then do some data analysis and visualization.

# %% [markdown]
# ### Scraping data
#
# From the AUR we have the following stats:
#
# Value | Count
# ---|---
# Packages | 42909
# Orphan Packages | 2566
# Packages added in the past 7 days | 158
# Packages updated in the past 7 days | 1252
# Packages updated in the past year | 16338
# Packages never updated | 9876
# Registered Users | 48850
# Trusted Users | 46
#
# 45557 packages found.	Page 1 of 183. 250 results per page.
#
# In addition to the Arch User Repository, we can also easily gather data for regular Arch Linux packages that are part of the core, community, multilib and extra categories. There are just under 10,000 non-AUR packages that are a core part of Arch Linux.

# %%
from selenium import webdriver
import re
import time
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import os
import requests

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import networkx

# %% [markdown]
# ## Correction
#
# Arch Linux makes a list of the core packages available, so it is not necessary to scrape the names of the packages. The packages are available here:
#
# [https://aur.archlinux.org/packages.gz](https://aur.archlinux.org/packages.gz).
#
# First we will loop through the 184 pages that list packages. This will us a series of HTML files that each contain 250 packages (with the following information: package name (and link), version, votes, popularity, description and maintainer).

# %%
# os.chdir('../html/pages/')
# driver = webdriver.PhantomJS()
# base_url = "https://aur.archlinux.org/packages/?SeB=nd&K=&outdated=&SB=n&SO=a&PP=250&do_Search=Go&O="
# for i in range(0,184):
#     driver.get(base_url+str(i*250))
#     time.sleep(3 + np.random.random())
#     html = driver.page_source.encode('utf-8')
#     name = "page_" + str(i)
#     package_list = open(name+'.txt', 'w+')
#     package_list.write(str(html))
#     package_list.close()

# %%
# os.chdir('../html/pages/')
# files = os.listdir()
# dict_list = []
# for file in files:     
#     f = open(file, 'r')
#     html = f.read()
#     b = BeautifulSoup(html, 'lxml')
#     try: 
#         packages = b.find_all('tr')[1:]
#         for package in packages:
#             data = package.find_all('td')
#             data_dict = {
#                          "name": data[0].find('a').text,
#                          "link": data[0].find('a')['href'],
#                          "version":data[1].text,
#                          "votes": int(data[2].text),
#                          "popularity": float(data[3].text), 
#                          "description": data[4].text, 
#                          "user": data[5].text.strip('\\n').strip('\\t').strip('\\n')
#                         }
#             dict_list.append(data_dict)
#         print(f)
#     except Error as e:
#         print(e)
#     b.decompose()
#     f.close()

# %%
cols = ['name', 'link', 'version', 'votes', 'popularity', 'description', 'user']
df = pd.DataFrame(dict_list,columns=cols)
df = df.drop_duplicates()
df.to_csv('../csv/aur_data.csv')
# Out:
# (45558, 7)

# %%
df = pd.read_csv('../csv/aur_data.csv', index_col=0)
df.shape() #45558,7

# %% [markdown]
# This looks good! We have have 45558 packages from the AUR, just one more package than the 45557 that were listed when we started scraping, and 9983 packages from Arch Linux. There is a lot of interesting data right here, but there is more information about each package at the package page in the AUR, so we can visit each package page to scrape additional data which includes related packages, comments, contributors, release dates. Here's an example of all the data we have about an individual package:

# %% [markdown]
# ## Individual Packages
#
# Let's take [Spotify](https://aur.archlinux.org/packages/spotify/) as an example of how the package meta-data is structured:
#
# #### Package Details: spotify 1.0.66.478-1
# Attribute | Value
# ---|---
# Git Clone URL: | https://aur.archlinux.org/spotify.git (read-only)
# Git Clone URL: | https://aur.archlinux.org/spotify.git (read-only)
# Package Base: | spotify
# Description: |A proprietary music streaming service
# Upstream URL: | http://www.spotify.com
# Licenses: | custom:"Copyright (c) 2006-2010 Spotify Ltd"
# Submitter: | gadget3000
# Maintainer: | AWhetter
# Last Packager: | AWhetter
# Votes: | 1268
# Popularity: | 49.768907
# First Submitted: | 2010-07-12 09:17
# Last Updated: | 2017-10-29 16:29
#
#
# Dependencies (15) | Required by (5)
# ---|---
# desktop-file-utils (desktop-file-utils-git) | blockify
# gconf (gconf-gtk2) | blockify-git
# glib2 (glib2-git, glib2-patched-thumbnailer, glib2-quiet, glib2-sched-policy) | spotify-adkiller-dns-block-git
# gtk2 (gtk2-patched-filechooser-icon-view, gtk2-patched-gdkwin-nullcheck, gtk2-ubuntu) | spotify-adkiller-git
# libcurl-compat (libcurl-compat-nostatic) |
# libsystemd (eudev-git, libeudev-systemd, libsystemd-eudev-standalone, libsystemd-git, libsystemd-selinux) |
# libx11 (libx11-nokeyboardgrab) |
# libxss |
# libxtst |
# nss (nss-hg) |
# openssl-1.0 (openssl-1.0-chacha20) |
# rtmpdump (rtmpdump-git, rtmpdump-ksv-git) |
# alsa-lib>=1.0.14 |
# ffmpeg0.10 (optional) – Adds support for playback of local files |
# zenity (qarma-git, zenity-gtk2) (optional) – Adds support for importing local files |
#
# (5) | Sources
# --- | ---
# (1) | http://repository.spotify.com/pool/non-free/s/spotify-client/spotify-client_1.0.66.478.g1296534d-39_amd64.deb (x86_64)
# (2) | http://repository.spotify.com/pool/non-free/s/spotify-client/spotify-client_1.0.66.478.g1296534d-39_i386.deb (i686)
# (3) | LICENSE
# (4) | spotify
# (5) | spotify.protocol
#
#
# #### Pinned Comments
#
# NicoHood commented on 2017-05-28 11:45
#
# >@Lenovsky There you go. Please upvote this topic if you wish to have spotify in the official ArchLinux [community] repository.
# >
# > https://community.spotify.com/t5/Desktop-Linux-Windows-Web-Player/Redistribute-Spotify-on-Linux-Distributions/m-p/1695334#M188735
#
# #### Latest Comments
#
# skiwithuge commented on 2017-11-23 11:27
#
# > 2017 11 23: need to change spotify version to spotify-client_1.0.67.582.g19436fa3-28_amd64.deb
# >
# >http://repository.spotify.com/pool/non-free/s/spotify-client/
#
# [...]

# %% [markdown]
# Not all packages list the same information. The spotify package doesn't have architecture, install size or download and install size like other packages do. Some packages have multiple maintainers. Let's write a script that tries to capture the available fields into a dictionary and then create a new DataFrame from that data.
#
# We may want to build a separate DataFrame for comments with user, date, comment, pinned/not pinned.
#
# For dependency relationshpis we can simply store a list of each and then use a graph package like NetworkX to analyze how the packages are related.
#
# Also, it will take some time to scrape all of this package data, so we should write our script in a way that can easily pick up from where it last stopped if we lose our connection during execution.

# %% [markdown]
# ## Update
#
# We can get the list of packages simply by going to `https://aur.archlinux.org/packages.gz`.

# %%
packages = requests.get('https://aur.archlinux.org/packages.gz').text
packages.split('\n')[1:]

# %%
base_url = 'https://aur.archlinux.org/packages/'
for package in packages:
        search_url = base_url+package + "/?comments=all"
        html = requests.get(search_url).text
        time.sleep(2)
        file_name = package + '.txt'
        f = open(file_name, 'w+')
        f.write(str(html))
        f.close()
    else: 
        print(f'Skip: {_}')

# %%
# os.chdir('../html/pkgs/')
# package_html_files = os.listdir()
# base_url = 'https://aur.archlinux.org/packages/'
# for _, package in df.iterrows():
#     file_name = str(package['name'] + '.txt')
#     if file_name not in package_html_files: 
#         name = package['name']
#         link = package['name']
#         search_url = base_url+link + "/?comments=all"
#         html = requests.get(search_url).text
#         time.sleep(2)
#         f = open(file_name, 'w+')
#         f.write(str(html))
#         f.close()
#     else: 
#         print(f'Skip: {_}')

# %%
# Out:
# ['w3watch',
#  'cant',
#  'php-pear',
#  'jzip',
#  'zork1',
#  'zork2',
#  'zork3',
#  'guifications-clearlooks2glo',
#  'atari-adventure',
#  'eclipse-subclipse',
#  'wallpaper-lightning',
#  'squirrelmail',
#  'atari-bowling',
#  'atari-breakout',
#  'atari-combat',
#  'atari-space-invaders',
#  'mrunit',
#  'gtk-gnutella',
#  'roundcubemail-plugin-markasjunk2',
#  'roundcubemail-plugin-chbox',
#  'roundcubemail-plugin-jquery-mobile',
#  'roundcubemail-plugin-mobile',
#  'eclipse-svnkit',
#  'eclipse-dltk-core',
#  'eclipse-emf',
#  'eclipse-dltk-javascript',
#  'eclipse-antlr-runtime',
#  'eclipse-dltk-shelled',
#  'eclipse-linuxtools',
#  'eclipse-dltk-python',
#  'eclipse-antlr4-runtime',
#  'eclipse-jsonedit',
#  'eclipse-goclipse',
#  'adwaita-dark-darose',
#  'roundcubemail-plugin-keyboard-shortcuts-ng',
#  'fceux-svn',
#  'ggmud-svn',
#  'libiriverdb',
#  'griver',
#  'blastem-hg',
#  'vecx-git',
#  'lib32-glib',
#  'lib32-gtk',
#  'qjoypad',
#  'qjoypad-svn',
#  'qjoypad-panzi-git',
#  'yumbootstrap-git',
#  'nesasm-git',
#  'yum-metadata-parser',
#  'libretro-fmsx-git',
#  'projectm-git',
#  'projectm-libvisual-git',
#  'projectm-pulseaudio-git',
#  'projectm-qt-git',
#  'projectm-test-git',
#  'projectm-jack-git',
#  'bubblemon',
#  'gno3dtet',
#  'gnusound',
#  'tutka',
#  'netpanzer',
#  'stratagus',
#  'festival-italian',
#  'eternallands',
#  'scourge',
#  'lives',
#  'drqueue',
#  'cytadela',
#  'pgworksheet',
#  'bitefusion',
#  'globs-svn',
#  'bugle',
#  'ri-li',
#  'globs-benchmarks-svn',
#  'dunelegacy',
#  'lumina',
#  'eternallands-sound',
#  'getlive',
#  'shadermaker',
#  'glsldevil',
#  'csl',
#  'brother-dcp350c',
#  'pacstats-hg',
#  'pacstats',
#  'cal3d-svn',
#  'php-pam',
#  'unscd',
#  'netatop',
#  'stem',
#  'scamper',
#  'graylog',
#  'bitcoinxt',
#  'nginx-pagespeed',
#  'bitcoind-unlimited',
#  'python-pysword',
#  'python2-pysword',
#  't-prot',
#  'mp3rename',
#  'plc',
#  'xtermcontrol',
#  'python2-bencode',
#  'python2-binplist',
#  'python2-dfvfs',
#  'python2-dfwinreg',
#  'python2-artifacts',
#  'python2-pytsk3',
#  'python2-libbde',
#  'python2-libesedb',
#  'python2-libevt',
#  'python2-libevtx',
#  'python2-libfsntfs',
#  'python2-libfwsi',
#  'python2-liblnk',
#  'python2-libmsiecf',
#  'python2-libolecf',
#  'python2-libqcow',
#  'python2-libregf',
#  'python2-libscca',
#  'python2-libsigscan',
#  'python2-libsmdev',
#  'python2-libsmraw',
#  'python2-libvhdi',
#  'python2-libvmdk',
#  'python2-libvshadow',
#  'python2-libewf',
#  'python2-dfdatetime',
#  'libvhdi',
#  'python2-acora',
#  'python2-efilter',
#  'audioconvert',
#  'gogglesmm-git',
#  'gogglesmm-develop-git',
#  'hangupsbot',
#  'python-quamash-git',
#  'qhangups',
#  'qspectrumanalyzer',
#  'python-reparser',
#  'python-quamash',
#  'pwgen-passphrase',
#  'macchiato-git',
#  'ft232r_prog',
#  'gr-dsd-git',
#  'rtl_power_fftw-git',
#  'python2-pyrtlsdr-git',
#  'python-pyrtlsdr-git',
#  'csdr-git',
#  'gr-dab-git',
#  'acarsdec',
#  'rtlsdr-airband-git',
#  'rtlsdr-scanner-git',
#  'shinysdr-git',
#  'python2-txws',
#  'python-txws',
#  'sdrangel-git',
#  'cubicsdr-git',
#  'python-signaller',
#  'serialdv-git',
#  'dsdcc-git',
#  'soapyosmo-git',
#  'soapyhackrf-git',
#  'cryptboot',
#  'pyxolotl',
#  'soapyairspy-git',
#  'libmirisdr4-git',
#  'cm256cc-git',
#  'limesuite-git',
#  'qspectrumanalyzer-git',
#  'simplesoapy',
#  'soapy_power',
#  'simplespectral',
#  'python-qt.py',
#  'python-setup_qt',
#  'libosmocore-git',
#  'jaxx',
#  'shepherd',
#  'qstat',
#  'doom3',
#  'quake4-demo',
#  'quake4',
#  'quake2',
#  'fuhquake',
#  'freeciv-svn',
#  'doom3-lms',
#  'birthday',
#  'teamspeak2',
#  'davtools',
#  'defrag',
#  'doom3-inhell',
#  'quake3',
#  'nwn-diamond',
#  'quake3-cpma',
#  'quake3-defrag',
#  'quake3-excessiveplus',
#  'quake3-osp',
#  'quake3-reactionq3',
#  'quake3-rocketarena',
#  'quake3-threewave',
#  'quake3-urbanterror',
#  'quake-par',
#  'savage',
#  'ezquake',
#  'quake-rocketarena',
#  'doom3-phantasm',
#  'quake4-multiplayer-demo',
#  'etqw',
#  'quake2-retexture',
#  'wolf',
#  'doom3-cdoom',
#  'quake3-stereoquake',
#  'gmameui',
#  'savage2',
#  'mpc-git',
#  'prey-demo',
#  'btrl',
#  'prey',
#  'ioquake3',
#  'tracks',
#  'quake3-defrag-maps',
#  'savage-xr',
#  'xqf',
#  'quake-qrp-textures',
#  'doom3-bin',
#  'maraschinoproject-git',
#  'ioquake3-git',
#  'xqf-git',
#  'qstat-git',
#  'xc3028l-fw',
#  'mopidy-local-sqlite',
#  'prometheus-node-exporter-bin',
#  'prometheus-bin',
#  'prometheus-mysqld-exporter-bin',
#  'alertmanager-bin',
#  'prometheus-haproxy-exporter-bin',
#  'packer-io-git',
#  'brother-dcpt300',
#  'libbinio',
#  'adplug',
#  'ocp',
#  'odamex',
#  'reminiscence',
#  'linux-mainline',
#  'linux-mainline-headers',
#  'linux-mainline-docs',
#  'acmetool-git',
#  'moc-svn',
#  'opencpn',
#  'aspell-nn',
#  'gaupol-git',
#  'kittypack-git',
#  'xmonad-git',
#  'xmonad-contrib-git',
#  'newlisp',
#  'gnuserv',
#  'gerbil-git',
#  'ipxe-netboot',
#  'tttool-git',
#  'csv2xls',
#  'xlslib',
#  'bvi',
#  'allin1',
#  'bcpp',
#  'ccal',
#  'xxdiff',
#  'vim-dirdiff',
#  'yaffs2utils-svn',
#  'vim-dotoutlinetree',
#  'vim-voom',
#  'lonote',
#  'upgradepic',
#  'vim-tabular-git',
#  'xxdiff-hg',
#  'fossil-tip',
#  'genseat-git',
#  'fix8-git',
#  'python2-grs-git',
#  'python2-googl-hg',
#  'sockperf-git',
#  'coin-or-symphony',
#  'airfoilspeakers',
#  'akonadi-googledata',
#  'libkqueue',
#  'frame',
#  'grail',
#  'geis',
#  'dmapd',
#  'jmeter-plugins-standard',
#  'jmeter-plugins-extraslib',
#  'nvme-cli',
#  'jmeter-plugins-manager',
#  'python-pretty-cron',
#  'python-mirobo',
#  'miio',
#  'drun',
#  'lib32-mesa-git',
#  'seventhsense',
#  'cndrvcups-lb',
#  'openrc',
#  'freecol-git',
#  'cndrvcups-common-lb',
#  'mesa-git',
#  'libdrm-git',
#  'lib32-libdrm-git',
#  'singularity-git',
#  'qxmledit',
#  'xf86-input-joystick',
#  'opentmpfiles',
#  'lib32-bcunit',
#  'dummy-opengl-driver-git',
#  'xorg-xdriinfo-git',
#  'alevt',
#  'enigma_sdl',
#  'xerces-c-2',
#  'xfce-theme-cobibird',
#  'faenza-fresh-icon-theme',
#  'gnome-encfs-manager',
#  'git-imerge-git',
#  'dotpac',
#  'kbd-bone',
#  'xbindkeys_config-gtk2',
#  'fortune-mod-bashfr',
#  'sysrqd',
#  'xkbset',
#  'perl-lingua-translate-google',
#  'perl-lingua-translate',
#  'perl-pod-constants',
#  'perl-http-proxy',
#  'xwax-jack',
#  'weboob-git',
#  'hellanzb-git',
#  'glipper',
#  'heyu',
#  'xombrero-gtk2-git',
#  'dvorak7min',
#  'foldingathome',
#  'fahcontrol',
#  'fahviewer',
#  'gnaughty',
#  'mp3cue',
#  'mp3cut',
#  'poc-fec',
#  'poc-3119',
#  'poc',
#  'mp3length',
#  'poc-2250',
#  'poc-http',
#  'pob-2250',
#  'pob-3119',
#  'pogg-http',
#  'pob-fec',
#  'ceemedia',
#  'bash-completion-xmms2',
#  'flv2x264',
#  'freeme2-svn',
#  'freeme2',
#  'openbox-xdgmenu',
#  'vim-bash-support',
#  'gtk2-theme-slickness',
#  'openbox-gnome-places',
#  'ape2mp3',
#  'festival-pl-em',
#  'napi-bash',
#  'gdm-old',
#  'gdm-old-faces',
#  'perl-opcodes',
#  'perl-b-c',
#  'perl-unix-pid',
#  'perl-shell-perl',
#  'perl-test-corpus-audio-mpd',
#  'pydefrag-bzr',
#  'perl-x-osd',
#  'perl-gtk2-ex-mplayerembed',
#  'perl-linux-inotify2',
#  'milena-data',
#  'milena',
#  'vim-perl-completion',
#  'perl-xml-xbel',
#  'milena-basewords',
#  'perl-string-urandom',
#  'perl-moosex-poe',
#  'milena-abc',
#  'milena-mplayer',
#  'xcursor-semi-transparent',
#  'milena-gtk',
#  'rhythmcat',
#  'rhythmcat-plugins',
#  'rhythmcat-plugins-extra',
#  'perl-ppix-utilities',
#  'perl-x11-aosd',
#  'perl-x11-idletime',
#  'perl-parallel-forkmanager',
#  'seamonkey-i18n-pl',
#  'perl-b-flags',
#  'seamonkey-i18n-tr',
#  'seamonkey-i18n-nb-no',
#  'seamonkey-i18n-nl',
#  'seamonkey-i18n-pt-pt',
#  'seamonkey-i18n-ru',
#  'seamonkey-i18n-lt',
#  'seamonkey-i18n-ja',
#  'seamonkey-i18n-it',
#  'seamonkey-i18n-es-es',
#  'seamonkey-i18n-fi',
#  'seamonkey-i18n-fr',
#  'seamonkey-i18n-hu',
#  'seamonkey-i18n-sk',
#  'seamonkey-i18n-sv-se',
#  'seamonkey-i18n-es-ar',
#  'seamonkey-i18n-ca',
#  'seamonkey-i18n-cs',
#  'seamonkey-i18n-de',
#  'seamonkey-i18n-en-gb',
#  'libreoffice-extension-languagetool',
#  'eiciel',
#  'perl-test-taint',
#  'perl-cairo-gobject',
#  'gdm-control',
#  'perl-net-mpd',
#  'gz-models',
#  'mixramp',
#  'perl-sys-filesystem',
#  'perl-getopt-std-strict',
#  'perl-sys-filesystem-mountpoint',
#  'perl-file-trash-freedesktop',
#  'perl-datetime-format-rfc3339',
#  'perl-datetime-format-atom',
#  'perl-www-mixcloud',
#  'perl-www-youtube-download',
#  'perl-www-offliberty',
#  'perl-string-bash',
#  'perl-uri-magnet',
#  'pluma-plugins',
#  'qsp-bin',
#  'daydreamer',
#  'perl-time-out',
#  'perl-defhash',
#  'perl-rinci',
#  'perl-term-progressbar-quiet',
#  'perl-file-moreutil',
#  'perl-sah',
#  'daydreamer-editor',
#  'disksearch',
#  'gddccontrol',
#  'ddccontrol',
#  'qtads',
#  'perl-log-any-iflog',
#  'checkupdates-aur',
#  'perl-checkupdates-aur',
#  'pluma-1.16',
#  'perl-subtitles',
#  'perl-prima',
#  'perl-math-currency',
#  'libcdk',
#  'qrfcview',
#  'linux-wave',
#  'linux-wave-headers',
#  'linux-wave-docs',
#  'python2-pyqtgraph',
#  'python-pyqtgraph',
#  'glslang-git',
#  'core',
#  'emane',
#  'usermount-git',
#  'oauth2_proxy',
#  'nodejs-pass-server-node',
#  'android-studio-beta',
#  'jasmine-gjs-git',
#  'itex2mml',
#  'choosewm',
#  'turnserver',
#  'pam_sasl',
#  'geben-on-emacs',
#  'pam_chroot',
#  'plascolin',
#  'perl-data-dumper-simple',
#  'mando-git',
#  'linux-usermode',
#  'linux-usermode-modules',
#  'gimp-plugin-id-photo',
#  'bugzilla-l10n-ja',
#  'bugzilla-l10n-ru',
#  'mozilla_password_dump-git',
#  'perl-svn-look',
#  'imapdedup',
#  'gimp-script-make-anaglyph',
#  'qemu-static',
#  'vde2-static',
#  'owncloud-app-roundcube',
#  'sniproxy',
#  'owncloud-app-notes-git',
#  'owncloud-app-music-git',
#  'perl-libapreq2',
#  'perl-redmine-api',
#  'digitemp',
#  'e1000e-dkms',
#  'i2c-ch341-dkms',
#  'fheroes2-svn',
#  'gpsdrive',
#  'imaputils',
#  'irda-utils',
#  'owncloud-app-spreed.me',
#  'ubi_reader',
#  'xemacs-all-packages',
#  'perl-ip-country',
#  'nextcloud-app-spreed.me',
#  'nextcloud-app-rainloop',
#  'nextcloud-app-mozilla_sync',
#  'milagro-crypto-c',
#  'xradio-git',
#  'nextcloud-app-jsxc',
#  'nextcloud-app-spreed',
#  'bluez-rfcomm',
#  'gerbera',
#  'perl-browser-open',
#  'htmail-view',
#  'hatexmpp-git',
#  'bluez-hcitool',
#  'slack-libpurple-git',
#  'jabrss-svn',
#  'python-rocket-errbot',
#  'errbot',
#  'whatsapp-purple-git',
#  'nrftool',
#  'purple-mattermost-spectrum2',
#  'xabber-websocket',
#  'xabber-web',
#  'libreoffice-online',
#  'nextcloud-app-richdocuments',
#  'scenarist',
#  'opentoonz',
#  'screentranslator',
#  'ultra_outliner',
#  'voxelquest',
#  'voxelquest-git',
#  'python-pygments-markdown-lexer',
#  'pulseaudio-git',
#  'moped',
#  'fairsplit',
#  'mywire-connect',
#  'repoctl',
#  'thefall',
#  'phpsysinfo',
#  'pfqueue',
#  'esets',
#  'ytd',
#  '602xmlfiller',
#  'mp3directcut',
#  'poweradmin',
#  'roundcube-plugin-sieverules',
#  'milter-spamd',
#  'xc3028-fw',
#  'bastet',
#  'dterm',
#  'perl-term-size',
#  'ekgping',
#  'perl-travel-routing-de-vrr',
#  'perl-travel-status-de-deutschebahn',
#  'perl-travel-status-de-vrr',
#  'icli',
#  'catlateral-damage',
#  'perl-travel-status-de-iris',
#  'qprint',
#  'intlfonts',
#  'perl-syntax-highlight-perl',
#  'perl-tk-codetext',
#  'perl-xml-nodefilter',
#  'perl-xml-libxml-iterator',
#  'tred',
#  'perl-xml-filter-domfilter-libxml',
#  'perl-xml-xupdate-libxml',
#  'xsh',
#  'perl-pml',
#  'perl-universal-does',
#  'perl-xml-compacttree',
#  'perl-treex-pml',
#  'ruby-docs-rdocs',
#  'css-2-docs',
#  'css-namespaces-3-docs',
#  'emacs-let-alist',
#  'html-4-docs',
#  'xhtml-modularization-1-docs',
#  'xhtml-1-docs',
#  'swagger-codegen',
#  'ntrviewer-git',
#  'leo',
#  'sgi-fonts',
#  'xmlcopyeditor',
#  'hdf4',
#  'elog',
#  'audiotools',
#  'python-tablib',
#  'python2-tablib',
#  'python2-pyhdf',
#  'ipe',
#  'dsrpdb',
#  'cgal-ipelets',
#  'ann',
#  'python2-fastcluster',
#  'ipe-tools-git',
#  'python2-cvxmod',
#  'fftw-mpich',
#  'ruby-pcap',
#  'perl-latexml',
#  'toolsched',
#  'kdeplasma-applets-fancytasks',
#  'gdbm183',
#  'safesignidentityclient',
#  'python-pychromecast-git',
#  'j8-git',
#  'compiz-manjaro',
#  'metacity2',
#  'linux-netbook',
#  'linux-netbook-headers',
#  'linux-jaguar',
#  'linux-jaguar-headers',
#  'xfce4-places-plugin',
#  'ftkimager',
#  'resetmsmice',
#  'motioneye',
#  'linux-lts41',
#  'linux-lts41-headers',
#  'linux-lts41-docs',
#  'linux-lts41-ck',
#  'linux-lts41-ck-headers',
#  'ubuntu-mate-themes',
#  'hyperscan-git',
#  'zfs-snap-manager',
#  'mbuffer',
#  'meanwhile',
#  'python2-os-diskconfig-python-novaclient-ext',
#  'python2-os-networksv2-python-novaclient-ext',
#  'python2-rax-backup-schedule-python-novaclient-ext',
#  'python2-rax-default-network-flags-python-novaclient-ext',
#  'python2-rackspace-novaclient',
#  'python2-pyrax',
#  'python2-rax-scheduled-images-python-novaclient-ext',
#  'python-rackspace-auth-openstack',
#  'python2-rackspace-auth-openstack',
#  'python2-keystoneclient-rackspace',
#  'python-keystoneclient-rackspace',
#  'python-rackspace-novaclient',
#  'python-rax-backup-schedule-python-novaclient-ext',
#  'python-rax-default-network-flags-python-novaclient-ext',
#  'python-os-networksv2-python-novaclient-ext',
#  'python-os-diskconfig-python-novaclient-ext',
#  'python-rax-scheduled-images-python-novaclient-ext',
#  'python2-os-virtual-interfacesv2-python-novaclient-ext',
#  'python-os-virtual-interfacesv2-python-novaclient-ext',
#  'ros-indigo-camera1394',
#  'ros-indigo-libnabo',
#  'ros-indigo-sick-tim',
#  'flatabulous-theme-git',
#  'guake-git',
#  'dcmtk',
#  'fnfx',
#  'pseint',
#  'otf-zilla-slab',
#  'ttf-zilla-slab',
#  'front-panel-designer',
#  'davix-git',
#  'slsnif',
#  'sigrok-firmware-saleae-logic16',
#  'pidgin-pushbullet-git',
#  'python2-purple-git',
#  'python-multi_key_dict',
#  'candra-themes-3.20-1',
#  'hope-gtk3-theme',
#  'maya-gtk3-theme',
#  'gtk-theme-gray-simple',
#  'kubernetes-kubectl',
#  'omi',
#  'chrome-window-title-bar-xfwm-theme',
#  'numix-holo-themes',
#  'graphiql-app',
#  'esperanza-git',
#  'seeks-git',
#  'xkeyboard-config-rub',
#  'gringo',
#  'quarry-git',
#  'opam-git',
#  'zbar-git',
#  'tokyocabinet-git',
#  'aspcud-svn',
#  'cbitcoin-git',
#  'aqsis',
#  'pfstools',
#  'vok',
#  'makehuman',
#  'loki-lib',
#  'gimp-plugin-dcamnoise2',
#  'ossec-server',
#  'gimp-plugin-texturize',
#  'ossec-agent',
#  'ossec-local',
#  'aacplusenc',
#  'amrenc',
#  'mp4tools',
#  '3delight',
#  'ttf-gentium-basic',
#  'jpdftweak',
#  'perl-panotools-script',
#  'ciopfs',
#  'nip2',
#  'csv2latex',
#  'asoundconf',
#  'unshake',
#  'immix',
#  'openexr_viewers',
#  'enblend-hg',
#  'tau',
#  'php-magickwand',
#  'hugin-hg',
#  'codeviz',
#  'discspan',
#  'autopano-sift-c-hg',
#  'bracket',
#  'eilin',
#  'ocropy',
#  'photivo-hg',
#  'massif-visualizer-git',
#  'lib32-tinyxml',
#  'backup-gmail',
#  'yafaray-git',
#  'vigra-git',
#  'bootp',
#  'java-swing-joxy-git',
#  'libpano13-hg',
#  'readymedia-transcode-git',
#  'yafaray-blender-exporter-git',
#  'octaforge-git',
#  'multiblend',
#  'glsl-debugger-git',
#  'blender-git',
#  'gdb-git',
#  'vogl-git',
#  'ja2-stracciatella-git',
#  'kcm-wacomtablet-frameworks-git',
#  'ocropy-git',
#  'heaptrack-git',
#  'tesseract-git',
#  'tesseract-data-jpn-git',
#  'tesseract-data-kir-git',
#  'tesseract-data-tgl-git',
#  'tesseract-data-grc-git',
#  'tesseract-data-yid-git',
#  'tesseract-data-tur-git',
#  'tesseract-data-uig-git',
#  'tesseract-data-bod-git',
#  'tesseract-data-deu_frak-git',
#  'tesseract-data-khm-git',
#  'tesseract-data-pol-git',
#  'tesseract-data-slv-git',
#  'tesseract-data-heb-git',
#  'tesseract-data-mya-git',
#  'tesseract-data-ces-git',
#  'tesseract-data-lat-git',
#  'tesseract-data-dan-git',
#  'tesseract-data-hrv-git',
#  'tesseract-data-fra-git',
#  'tesseract-data-kat_old-git',
#  'tesseract-data-ita-git',
#  'tesseract-data-uzb_cyrl-git',
#  'tesseract-data-afr-git',
#  'tesseract-data-ell-git',
#  'tesseract-data-tgk-git',
#  'tesseract-data-jav-git',
#  'tesseract-data-hin-git',
#  'tesseract-data-mkd-git',
#  'tesseract-data-spa-git',
#  'tesseract-data-san-git',
#  'tesseract-data-dan_frak-git',
#  'tesseract-data-bul-git',
#  'tesseract-data-deu-git',
#  'tesseract-data-hat-git',
#  'tesseract-data-kan-git',
#  'tesseract-data-spa_old-git',
#  'tesseract-data-amh-git',
#  'tesseract-data-urd-git',
#  'tesseract-data-est-git',
#  'tesseract-data-sin-git',
#  'tesseract-data-eus-git',
#  'tesseract-data-slk_frak-git',
#  'tesseract-data-chr-git',
#  'tesseract-data-tel-git',
#  'tesseract-data-isl-git',
#  'tesseract-data-swa-git',
#  'tesseract-data-sqi-git',
#  'tesseract-data-nld-git',
#  'tesseract-data-slk-git',
#  'tesseract-data-mal-git',
#  'tesseract-data-lao-git',
#  'tesseract-data-kat-git',
#  'tesseract-data-dzo-git',
#  'tesseract-data-ita_old-git',
#  'tesseract-data-frk-git',
#  'tesseract-data-srp-git',
#  'tesseract-data-aze-git',
#  'tesseract-data-frm-git',
#  'tesseract-data-ceb-git',
#  'tesseract-data-lit-git',
#  'tesseract-data-tha-git',
#  'tesseract-data-cat-git',
#  'tesseract-data-osd-git',
#  'tesseract-data-ind-git',
#  'tesseract-data-asm-git',
#  'tesseract-data-vie-git',
#  'tesseract-data-tir-git',
#  'tesseract-data-tam-git',
#  'tesseract-data-por-git',
#  'tesseract-data-cym-git',
#  'tesseract-data-epo-git',
#  'tesseract-data-srp_latn-git',
#  'tesseract-data-ron-git',
#  'tesseract-data-ben-git',
#  'tesseract-data-nep-git',
#  'tesseract-data-ukr-git',
#  'tesseract-data-msa-git',
#  'tesseract-data-bel-git',
#  'tesseract-data-hun-git',
#  'tesseract-data-swe-git',
#  'tesseract-data-eng-git',
#  'tesseract-data-nor-git',
#  'tesseract-data-uzb-git',
#  'tesseract-data-enm-git',
#  'tesseract-data-lav-git',
#  'tesseract-data-equ-git',
#  'tesseract-data-kur-git',
#  'tesseract-data-aze_cyrl-git',
#  'tesseract-data-chi_sim-git',
#  'tesseract-data-kor-git',
#  'tesseract-data-rus-git',
#  'tesseract-data-mlt-git',
#  'tesseract-data-iku-git',
#  'tesseract-data-chi_tra-git',
#  'tesseract-data-glg-git',
#  'tesseract-data-guj-git',
#  'tesseract-data-syr-git',
#  'tesseract-data-bos-git',
#  'tesseract-data-pan-git',
#  'tesseract-data-ori-git',
#  'tesseract-data-pus-git',
#  'tesseract-data-fas-git',
#  'tesseract-data-mar-git',
#  'tesseract-data-fin-git',
#  'tesseract-data-kaz-git',
#  'tesseract-data-ara-git',
#  'tesseract-data-gle-git',
#  'kcm-wacomtablet',
#  'rawtherapee-git',
#  'glogg',
#  'okimfpsdrv',
#  'pion',
#  'exult-git',
#  'embree-bvh_build-git',
#  'eos_portable_archive',
#  'gimp-plugin-mathmap',
#  'evolus-pencil-git',
#  'java3d',
#  'gkrellm-fmonitor',
#  'chgrep',
#  'mp3val',
#  'vok_sk',
#  'perl-crypt-rijndael',
#  'gimp-plugin-refocusit',
#  'trophy',
#  'amoebax',
#  'gkrellm-hddtemp',
#  'logintop10',
#  'gkrellm2-multiping',
#  'avinfo',
#  'pho',
#  'disktype',
#  'gstatz',
#  'panomatic',
#  'iverbs_bin',
#  'uniso',
#  'editphotos',
#  'jpegtran_crop_bin',
#  'xtraceroute',
#  'nmonmerge',
#  'nmon2rrd',
#  'asciisec',
#  'discwrapper',
#  'ksar_bin',
#  'robombs_bin',
#  'bdfedit',
#  'sdlblocks',
#  'vinetto',
#  'osgg',
#  'xlite_bin',
#  'perl-set-object',
#  'orp-svn',
#  'omnitux',
#  'mdfextract',
#  'bsod',
#  'soundsort',
#  'tcpconsole',
#  'perl-net-arp',
#  'racer',
#  'fotbal',
#  'kulic',
#  'redeemer',
#  'sem',
#  'gvolwheel',
#  'fbctrl',
#  'enemylines7',
#  'gosm',
#  'flac2mp3',
#  'caster-demo',
#  'antigravitaattori',
#  'animtext',
#  'surl',
#  'registrator',
#  'xmltvproducer-svn',
#  'gish-demo',
#  'bethewumpus',
#  'netemul',
#  'deadspace',
#  'zelvici-svn',
#  'cacheprinter',
#  'perl-file-path',
#  'perl-gnome2-print',
#  'pylibpcap',
#  'perl-io-stty',
#  'uxtank',
#  'libdes',
#  'bennugd-core',
#  'bennugd-modules',
#  'railroadrampage',
#  'gcrontab',
#  'mullerfoto-fotostar_de',
#  'mullerfoto-fotostar_cz',
#  'mullerfoto-fotostar_sk',
#  'linchat',
#  'perl-proc-parallelloop',
#  'ssvnc',
#  'gadmin-openvpn-server',
#  'tamagotchi_boxing',
#  'wink',
#  'grappling_hook_demo',
#  'nixieclock',
#  'gfusion-demo',
#  'jvgs',
#  'puzsion',
#  'mobac-svn',
#  'gimp-fix-ca',
#  'flac2ogg',
#  'taginfo',
#  'cropgui',
#  'perl-gnome2-vte',
#  'epm',
#  'xwit',
#  'lentilwars',
#  'perl-math-polygon',
#  'perl-math-geometry-planar-gpc-polygon',
#  'perl-math-polygon-tree',
#  'happycamel',
#  'hedgewars-hg',
#  'touchtyper',
#  'py3-bsddb',
#  'algodoo',
#  'psani-profi',
#  'fdmf',
#  'mofilereader',
#  'socketw',
#  'jdatestamp',
#  'libjpeg-droppatch',
#  'andyetitmoves-demo',
#  'andyetitmoves',
#  'bakonf',
#  'olpw',
#  'catan-cow-client',
#  'eyeocr',
#  'retropong',
#  'retrotetris',
#  'retrobreak',
#  'nightsky',
#  'connect',
#  'diodon',
#  'osmchange',
#  'bournal',
#  'scrabble3d',
#  'grappling_hook',
#  'osmosis',
#  'mobac',
#  'pbftoosm',
#  'pbf2osm-git',
#  'regxml-git',
#  'perl-uuid',
#  'steelstorm2-hib',
#  'remotebox',
#  'ccfe',
#  'perl-gtk2-sourceview2',
#  'jpegtran_crop',
#  'voxatron',
#  'perl-email-outlook-message',
#  'csfml-bin',
#  'airhockey-git',
#  'swet',
#  'clanlib10',
#  'gpxviewer-bzr',
#  ...]
